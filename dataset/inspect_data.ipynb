# %%
from teeth_dataset import TeethDataset
import os, sys
import json

# %%
ROOT_DIR = os.path.abspath("../")
sys.path.append(ROOT_DIR)
DIR = os.path.join(ROOT_DIR, "data/Radiographs")
ANNOTATION_DIR = os.path.join(ROOT_DIR, "data/Segmentation/teeth_polygon_chunk_1.json")

# %% [markdown]
# ## Dataset

# %%
dataset = TeethDataset()
dataset.load_teeth(DIR, "train", ANNOTATION_DIR)
dataset.prepare()
print("Image Count: {}".format(len(dataset.image_ids)))
print("Class Count: {}".format(dataset.num_classes))
for i, info in enumerate(dataset.class_info):
    print("{:3}. {:50}".format(i, info['name']))
# Out:
# Image Count: 4
# Class Count: 33
#   0. BG
#   1. tooth_5
#   2. tooth_15
#   3. tooth_7
#   4. tooth_9
#   5. tooth_28
#   6. tooth_3
#   7. tooth_1
#   8. tooth_16
#   9. tooth_18
#  10. tooth_20
#  11. tooth_32
#  12. tooth_12
#  13. tooth_23
#  14. tooth_19
#  15. tooth_6
#  16. tooth_22
#  17. tooth_21
#  18. tooth_26
#  19. tooth_17
#  20. tooth_11
#  21. tooth_4
#  22. tooth_10
#  23. tooth_2
#  24. tooth_8
#  25. tooth_31
#  26. tooth_25
#  27. tooth_29
#  28. tooth_13
#  29. tooth_14
#  30. tooth_27
#  31. tooth_24
#  32. tooth_30

# %%
smaple_img = dataset.image_info[0]
print(json.dumps(smaple_img, indent=2))
# Out:
# {
#   "id": "797.jpg",
#   "source": "teeth",
#   "path": "d:\\main\\study\\IT\\ML\\Code\\project\\Segmentation-Teeth-by-Simple-Mask-R-CNN\\data/Radiographs\\train\\797.jpg",
#   "width": 1615,
#   "height": 840,
#   "objects": [
#     {
#       "class_id": 1,
#       "polygons": [
#         [
#           [
#             517,
#             380
#           ],
#           [
#             518,
#             379
#           ],
#           [
#             519,
#             380
#           ],
#           [
#             519,
#             381
#           ],
#           [
#             518,
#             382
#           ],
#           [
#             515,
#             382
#           ],
#           [
#             514,
#             381
#           ],
#           [
#             515,
#             380
#           ]
#         ],
#         [
#           [
#             512,
#             380
#           ]
#         ],
#         [
#           [
#             527,
#             379
# ...
